# %% [markdown]
# ## Madeline's!

# %%
! conda install bioconda::ncbi-genome-download
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - defaults
#  - bioconda
# Platform: linux-64
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
! ncbi-genome-download --help
# Out:
# usage: ncbi-genome-download [-h] [-s {refseq,genbank}] [-F FILE_FORMATS]
#                             [-l ASSEMBLY_LEVELS] [-g GENERA] [--genus GENERA]
#                             [--fuzzy-genus] [-S STRAINS] [-T SPECIES_TAXIDS]
#                             [-t TAXIDS] [-A ASSEMBLY_ACCESSIONS]
#                             [--fuzzy-accessions] [-R REFSEQ_CATEGORIES]
#                             [--refseq-category REFSEQ_CATEGORIES] [-o OUTPUT]
#                             [--flat-output] [-H] [-P] [-u URI] [-p N] [-r N]
#                             [-m METADATA_TABLE] [-n] [-N] [-v] [-d] [-V]
#                             [-M TYPE_MATERIALS]
#                             groups
#
# positional arguments:
#   groups                The NCBI taxonomic groups to download (default: all).
#                         A comma-separated list of taxonomic groups is also
#                         possible. For example: "bacteria,viral"Choose from:
# ...

# %%
! ncbi-genome-download -s genbank -F 'protein-fasta' -A GCAs_to_download_Ef.txt -o protein_fastas/ --flat-output -v bacteria
# Out:
# INFO: Using cached summary.
# INFO: Checking record 'GCA_001298485.1'
# INFO: Checking record 'GCA_001412695.1'
# INFO: Checking record 'GCA_001518735.1'
# INFO: Checking record 'GCA_001587115.1'
# INFO: Checking record 'GCA_001635875.1'
# INFO: Checking record 'GCA_001720945.1'
# INFO: Checking record 'GCA_001720965.1'
# INFO: Checking record 'GCA_001720985.1'
# INFO: Checking record 'GCA_001721005.1'
# INFO: Checking record 'GCA_001721025.1'
# INFO: Checking record 'GCA_001721065.1'
# INFO: Checking record 'GCA_001721085.1'
# INFO: Checking record 'GCA_001721105.1'
# INFO: Checking record 'GCA_001721905.1'
# INFO: Checking record 'GCA_001750885.1'
# INFO: Checking record 'GCA_001886635.1'
# INFO: Checking record 'GCA_001895905.1'
# INFO: Checking record 'GCA_001953235.1'
# INFO: Checking record 'GCA_001953255.1'
# INFO: Checking record 'GCA_002007625.1'
# INFO: Checking record 'GCA_002024245.1'
# ERROR: No entry for file ending in '_protein.faa.gz'
# ...

# %%
! ncbi-genome-download -s genbank -F 'protein-fasta' -A GCAs_to_download_Ab.txt -o protein_fastas/ --flat-output -v bacteria
# Out:
# INFO: Using cached summary.
# INFO: Checking record 'GCA_000695855.3'
# INFO: Checking record 'GCA_000746605.1'
# INFO: Checking record 'GCA_000746645.1'
# INFO: Checking record 'GCA_000761175.1'
# INFO: Checking record 'GCA_000794125.2'
# INFO: Checking record 'GCA_000814345.1'
# INFO: Checking record 'GCA_000820665.1'
# ERROR: No entry for file ending in '_protein.faa.gz'
# INFO: Checking record 'GCA_000820685.1'
# ERROR: No entry for file ending in '_protein.faa.gz'
# INFO: Checking record 'GCA_000828935.1'
# INFO: Checking record 'GCA_000830055.1'
# INFO: Checking record 'GCA_000963815.1'
# INFO: Checking record 'GCA_001026965.1'
# INFO: Checking record 'GCA_001077555.2'
# INFO: Checking record 'GCA_001077565.2'
# INFO: Checking record 'GCA_001077655.1'
# INFO: Checking record 'GCA_001077675.1'
# INFO: Checking record 'GCA_001077965.2'
# INFO: Checking record 'GCA_001261895.2'
# INFO: Checking record 'GCA_001399655.1'
# INFO: Checking record 'GCA_001457535.1'
# ...

# %%
! ncbi-genome-download -s genbank -F 'protein-fasta' -A GCAs_to_download_E.txt -o protein_fastas/ --flat-output -v bacteria
# Out:
# INFO: Using cached summary.
# INFO: Checking record 'GCA_000770155.1'
# INFO: Checking record 'GCA_001708345.1'
# INFO: Checking record 'GCA_002303275.1'
# INFO: Checking record 'GCA_002982195.1'
# INFO: Checking record 'GCA_004193715.1'
# INFO: Checking record 'GCA_004801515.1'
# INFO: Checking record 'GCA_004801535.1'
# INFO: Checking record 'GCA_004801595.1'
# INFO: Checking record 'GCA_009707405.1'
# INFO: Checking record 'GCA_013375935.1'
# INFO: Checking record 'GCA_013376815.1'
# INFO: Checking record 'GCA_014169295.1'
# INFO: Checking record 'GCA_016864115.1'
# ERROR: No entry for file ending in '_protein.faa.gz'
# INFO: Checking record 'GCA_018140965.1'
# INFO: Checking record 'GCA_019047105.1'
# INFO: Checking record 'GCA_019265065.1'
# ERROR: No entry for file ending in '_protein.faa.gz'
# INFO: Checking record 'GCA_019265085.1'
# ERROR: No entry for file ending in '_protein.faa.gz'
# INFO: Checking record 'GCA_019265105.1'
# ...

# %%
! ncbi-genome-download -s genbank -F 'protein-fasta' -A GCAs_to_download_Kp.txt -o protein_fastas/ --flat-output -v bacteria
# Out:
# INFO: Using cached summary.
# INFO: Checking record 'GCA_001021995.1'
# INFO: Checking record 'GCA_001559215.2'
# INFO: Checking record 'GCA_001571545.2'
# INFO: Checking record 'GCA_001593585.2'
# INFO: Checking record 'GCA_002591115.1'
# INFO: Checking record 'GCA_002796405.1'
# INFO: Checking record 'GCA_002796425.1'
# INFO: Checking record 'GCA_002796525.1'
# INFO: Checking record 'GCA_002948835.2'
# INFO: Checking record 'GCA_003546885.1'
# INFO: Checking record 'GCA_003812185.1'
# INFO: Checking record 'GCA_006874725.1'
# INFO: Checking record 'GCA_007632255.1'
# INFO: Checking record 'GCA_008693885.1'
# INFO: Checking record 'GCA_008727695.1'
# INFO: Checking record 'GCA_008931665.1'
# INFO: Checking record 'GCA_009732795.1'
# INFO: Checking record 'GCA_009732815.1'
# INFO: Checking record 'GCA_009732835.1'
# INFO: Checking record 'GCA_009909445.1'
# INFO: Checking record 'GCA_010509815.1'
# ERROR: No entry for file ending in '_protein.faa.gz'
# ...
